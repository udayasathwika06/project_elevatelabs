# %% [markdown]
# <a href="https://colab.research.google.com/github/udayasathwika06/project_elevatelabs/blob/main/Python_Based_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# Load data
df = pd.read_csv('retail_transaction_data.csv')

# Correlation
correlation = df[['Inventory_Days', 'Profit']].corr()
print("🔹 Correlation Matrix:\n", correlation)

# Visualization
sns.regplot(x='Inventory_Days', y='Profit', data=df)
plt.title('Correlation Between Inventory Days and Profit')
plt.tight_layout()
plt.show()
# Out:
# 🔹 Correlation Matrix:
#                  Inventory_Days    Profit
# Inventory_Days        1.000000 -0.073573
# Profit               -0.073573  1.000000
